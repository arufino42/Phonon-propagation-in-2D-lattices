# %%
k=100
import numpy
from matplotlib import pyplot;
import pylab
from pylab import genfromtxt;  
mat1 = genfromtxt("grafico_s_xy.txt");
mat2 = genfromtxt("grafico_s_y.txt");
mat3 = genfromtxt("grafico_s_z.txt");
#mat4 = genfromtxt("file_s_12_37.txt");
t= numpy.linspace(1, k, k)
pyplot.plot(t,mat1 , label = "data1");
pyplot.plot(t,mat2 , label = "data1");
pyplot.plot(t,mat3 , label = "data1");
pyplot.legend("1234");
pylab.savefig('plot.png')
pyplot.show();
